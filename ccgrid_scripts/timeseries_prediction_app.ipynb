# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/home/jolivera/Documents/CloudSkin/Time-Series-Library/ccgrid_scripts/data/torchserve_gym_observation-test.csv')

# %%
df["node_4torchserve_app_user"].hist(bins=100)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (1250, 41)
